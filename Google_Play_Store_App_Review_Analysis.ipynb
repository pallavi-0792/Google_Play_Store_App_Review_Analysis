# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavi-0792/Google_Play_Store_App_Review_Analysis/blob/main/Google_Play_Store_App_Review_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Google play store app review analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Google Play Store is largest and most popularized Android app stores worldwide. With its broad collection of apps and a assets of data, it presents an optimal occasion for creating effective models and relating trends and future challenges.
# In this EDA design, we used two datasets one containing Play Store attributes and the other consisting of user reviews. The first dataset encompasses 13 different attributes, while the alternate dataset provides five another features for data manipulation and analysis.
# With the help of tools like Python, NumPy, Pandas, Matplotplotlib, Seaborn, Plotly I am able to perform this EDA. Here performed Data Cleaning, Data Processing, Data analysis, Data visualization and got some desirable plots. These plots helped a lot to convert a numeric data into easy pictorial representation, with which a user can easily read and understand the data.
# ultimately,I got some key points, which will help a developer to know on which region they should work to build a successful application among all with high rate of interest.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Pallavi-1608/Google_Play_Store_App_Review_Analysis_EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Finding the key factors that driving app performance and engagement by examining and analyzing the data.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# This initiative aims to provide businesses and app developers with an understanding of the elements that contribute to the success of their apps. Relevant KPIs will be found by examining the play_store_data and user_review_data datasets. This data will be utilized to offer insights and suggestions on how to raise income, maintain user retention, improve marketing strategies, and boost app engagement. In ultimately, I want to assist companies in developing profitable apps that keep users happy and drive growth.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
  #mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#reading csv file-1
play_store_app_df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project Dataset/Play Store Data.csv')

# %%
#reading csv file 2
play_store_user_review_df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Project Dataset/User Reviews.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Display the Play Store App data
play_store_app_df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Display the Play Store App data last rows
play_store_app_df1.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
# Display the Play Store user review data
play_store_user_review_df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
# Display the Play Store user review data last rows
play_store_user_review_df2.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Display the shape play store App data
play_store_app_df1.shape
# Out:
# (10841, 13)

# %% [markdown]
# In first data set we have 10841 rows and 13 columns

# %%
# Display the shape of Play Store user review data
play_store_user_review_df2.shape
# Out:
# (64295, 5)

# %% [markdown]
# In second data set we have 64295 rows and 5 columns

# %% [markdown]
# ### What did you know about your dataset?

# %%
# Information about the second dataset Play Store User Review
play_store_user_review_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
# Information about the First dataset Play Store App
play_store_app_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# By diagnosing the data frame, we know that:
#
# -There are 13 columns of properties with 10841 rows of data.
#
# -Column 'Reviews', 'Size', 'Installs' and 'Price' are in the type of 'object'
#
# -Values of column 'Size' are strings representing size in 'M' as Megabytes, 'k' as kilobytes and also 'Varies with devices'.
#
# -Values of column 'Installs' are strings representing install amount with symbols such as ',' and '+'.
#
# -Values of column 'Price' are strings representing price with symbol '$'.

# %% [markdown]
# **Coverting column Reviews into int datatype**

# %%
# Check if all the values in the column Reviews is numeric.
play_store_app_df1.Reviews.str.isnumeric().sum()
# Out:
# 10840

# %% [markdown]
# Out of 10841 objects, 10840 values are numeric and 1 value is non-numeric.

# %%
# Check which value in column Reviews is non-numeric.

play_store_app_df1[~play_store_app_df1.Reviews.str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# In above row data in column Reviews and Categaory are wrong so We can fix it by setting the Category or we deleting this entry for now.

# %%
# Deleting the entry index 10472

play_store_app_df1 = play_store_app_df1.drop(play_store_app_df1.index[10472])

# %%
# Now convert the values in the column Reviews as int datatype.

play_store_app_df1['Reviews'] = play_store_app_df1['Reviews'].astype(int)

# %% [markdown]
# **Coverting datatype of column Size into int**

# %%
play_store_app_df1['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %% [markdown]
# Here,converting the column Size to int datatype, but the data has suffixes k and M so we have to replace k and M with their values to convert them to numeric Also, deal with 'Varies with device'.

# %%
# Convert all apps size in mb data and drop some sign for coverting it into float data type
play_store_app_df1['Size'] = play_store_app_df1['Size'].apply(lambda x: str(x).replace('Varies with device', '20') if 'Varies with device' in str(x) else x)
play_store_app_df1['Size'] = play_store_app_df1['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else x)
play_store_app_df1['Size'] = play_store_app_df1['Size'].apply(lambda x: str(x).replace(',', '') if 'M' in str(x) else x)
play_store_app_df1['Size'] = play_store_app_df1['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)
play_store_app_df1['Size'] = play_store_app_df1['Size'].apply(lambda x: float(x))

# %%
# After converted Size column to int
play_store_app_df1["Size"].unique()
# Out:
# array([1.90e+01, 1.40e+01, 8.70e+00, 2.50e+01, 2.80e+00, 5.60e+00,
#        2.90e+01, 3.30e+01, 3.10e+00, 2.80e+01, 1.20e+01, 2.00e+01,
#        2.10e+01, 3.70e+01, 2.70e+00, 5.50e+00, 1.70e+01, 3.90e+01,
#        3.10e+01, 4.20e+00, 7.00e+00, 2.30e+01, 6.00e+00, 6.10e+00,
#        4.60e+00, 9.20e+00, 5.20e+00, 1.10e+01, 2.40e+01, 9.40e+00,
#        1.50e+01, 1.00e+01, 1.20e+00, 2.60e+01, 8.00e+00, 7.90e+00,
#        5.60e+01, 5.70e+01, 3.50e+01, 5.40e+01, 2.01e-01, 3.60e+00,
#        5.70e+00, 8.60e+00, 2.40e+00, 2.70e+01, 2.50e+00, 1.60e+01,
#        3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+01, 3.20e+01,
#        5.40e+00, 1.80e+01, 1.10e+00, 2.20e+00, 4.50e+00, 9.80e+00,
#        5.20e+01, 9.00e+00, 6.70e+00, 3.00e+01, 2.60e+00, 7.10e+00,
#        3.70e+00, 2.20e+01, 7.40e+00, 6.40e+00, 3.20e+00, 8.20e+00,
#        9.90e+00, 4.90e+00, 9.50e+00, 5.00e+00, 5.90e+00, 1.30e+01,
#        7.30e+01, 6.80e+00, 3.50e+00, 4.00e+00, 2.30e+00, 7.20e+00,
# ...

# %% [markdown]
# **changing the datatype of column Install**

# %%
play_store_app_df1.Installs.unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
# we have found "+","," signs, so removing that and conveting datatype to int
play_store_app_df1['Installs']=play_store_app_df1['Installs'].apply(lambda x: x.replace("+",""))
play_store_app_df1['Installs']=play_store_app_df1['Installs'].apply(lambda x: x.replace(",",""))
play_store_app_df1['Installs']=play_store_app_df1['Installs'].apply(lambda x:int(x))

# %%
# After converting the Insalls coloumn
play_store_app_df1['Installs'].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,         50,        100,
#               500,         10,          1,          5,          0])

# %% [markdown]
# **Changing the datatype of column Price**

# %%
play_store_app_df1['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
# for converting datatype of column Price from object to float we have remove the "$" sign
play_store_app_df1['Price']=play_store_app_df1['Price'].apply(lambda x : x.replace("$",""))
play_store_app_df1['Price']=play_store_app_df1['Price'].apply(lambda x : float(x))

# %%
play_store_app_df1.Price.unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
# display the cleaned Play Store App Dataset
play_store_app_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.2+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset  Duplicate Value Count
duplicates_app=play_store_app_df1.duplicated()
duplicate_app_count=duplicates_app.sum()
print('Play Store App Data Duplicate Value Count : ',duplicate_app_count)
# Out:
# Play Store App Data Duplicate Value Count :  483

# %%
# Unique apps
df1 = play_store_app_df1["App"].nunique()
print('Play Store App Data Unique app Count : ',df1)
# Out:
# Play Store App Data Unique app Count :  9659

# %%
# remove the duplicat app
play_store_app_df1=play_store_app_df1.drop_duplicates(subset='App')
print("Play Store App Data after removing duplicate apps :- ")
play_store_app_df1.head()
# Out:
# Play Store App Data after removing duplicate apps :-
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# ####Deleting the unwanted Columns

# %%
# Delete unwanted columns
play_store_app_df1.drop(['Android Ver', 'Current Ver', 'Last Updated'], axis=1, inplace=True)

# %% [markdown]
# #### Missing Values/Null Values

# %% [markdown]
# Handling Null values of first dataset-- Play Store App Data

# %%
# Null Values Count per variable
null_values_count = play_store_app_df1.isnull().sum()
null_values_count
# Out:
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# dtype: int64

# %%
# Visualizing the null values
# Ploting a bar chart for the fraction of null values in each variable.
play_store_app_df1.isnull().sum().plot.bar(figsize=(10,4))
plt.ylabel('Number of null values')
plt.xlabel('Variables')
plt.title('Quantifying null data')
# Out:
# Text(0.5, 1.0, 'Quantifying null data')

# %% [markdown]
# ####There are 1463 rows having null values under column 'Rating'. so, we decided to replace the null values with mean of overall 'Rating' values.

# %%
# replacing all null values of column Rating witn mean of overall Rating values
play_store_app_df1['Rating']=play_store_app_df1['Rating'].fillna(play_store_app_df1['Rating'].mean())

# %%
# after replacing we again check dataset
play_store_app_df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# dtype: int64

# %% [markdown]
# **Cleaned Play Store App Dataset**

# %%
# cleaned dataset
play_store_app_df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# Handling null values of second dataset--User Reviews

# %%
# Null Values Count per variable
play_store_user_review_df2.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
#checking sentiment coulumn
play_store_user_review_df2['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive    23998
# Negative     8271
# Neutral      5163
# Name: count, dtype: int64

# %% [markdown]
#  Here in sentiment column putting any random values may lead to change the result of this analysis so we will drop all the rows having null values to get a proper result

# %%
# removing the null values
play_store_user_review_df2.dropna(inplace=True)

# %%
# After deleting null values again we check
play_store_user_review_df2.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
play_store_user_review_df2.shape
# Out:
# (37427, 5)

# %% [markdown]
# **Cleaned Play Store User Review Dataset**

# %%
# Cleaned second dataset
play_store_user_review_df2.head(10)
# Out:
#                       App                                  Translated_Review  \
# 0   10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1   10 Best Foods for You    This help eating healthy exercise regular basis
# 3   10 Best Foods for You         Works great especially going grocery store
# 4   10 Best Foods for You                                       Best idea us
# 5   10 Best Foods for You                                           Best way
# 6   10 Best Foods for You                                            Amazing
# 8   10 Best Foods for You                               Looking forward app,
# 9   10 Best Foods for You              It helpful site ! It help foods get !
# 10  10 Best Foods for You                                          good you.
# 11  10 Best Foods for You  Useful information The amount spelling errors ...
#
#    Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0   Positive                1.00                0.533333
# ...

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset first Columns
play_store_app_df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres'],
#       dtype='object')

# %%
# Dataset first Describe
play_store_app_df1.describe()
# Out:
#             Rating       Reviews         Size      Installs        Price
# count  9659.000000  9.659000e+03  9659.000000  9.659000e+03  9659.000000
# mean      4.173243  2.165926e+05    20.345075  7.777507e+06     1.099299
# std       0.494312  1.831320e+06    20.394348  5.375828e+07    16.852152
# min       1.000000  0.000000e+00     0.008500  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01     5.300000  1.000000e+03     0.000000
# 50%       4.200000  9.670000e+02    16.000000  1.000000e+05     0.000000
# 75%       4.500000  2.940100e+04    25.000000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09   400.000000

# %%
# Dataset second columns
play_store_user_review_df2.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset second Describe
play_store_user_review_df2.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37427.000000            37427.000000
# mean             0.182171                0.492770
# std              0.351318                0.259904
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Dataset-1**
#
# **App**: It contains the name of the app with a short description.
#
# **Category:** This section gives the category to which an app belongs
#               In this dataset, the apps are divided among 33 categories.
#
# **Size:** The disk space required to install the respective app.
#
# **Rating:** The average rating given by the users for the respective app. It can be in between 1 and 5.
#
# **Reviews:** The number of users that have dropped a review for the respective app.
#
# **Installs:** The approximate number of times the respective app was installed.
#
# **Type:** It states whether an app is free to use or paid.
#
# **Price:** It gives the price payable to install the app. For free type apps, the price is zero.
#
# **Content rating:** It states which age group is suitable to consume the content of the respective app.
#
# **Genres:** It gives the genre(s) to which the respective app belongs.
#
# **Last updated:** It gives the day in which the latest update for the respective app was released.
#
# **Current Ver:** It gives the current version of the respective app.
#
# **Android Ver:** It gives the android version of the respective app.

# %% [markdown]
# **Dataset-2**
#
# **App:** It contains the name of the app with a short description
#
# **Translated_Review:** It contains the English translation of the review dropped by the user of the app.
#
# **Sentiment:** It gives the attitude/emotion of the writer. It can be ‘Positive’, ‘Negative’, or ‘Neutral’.
#
# **Sentiment_Polarity:** It gives the polarity of the review. Its range is [-1,1], where 1 means ‘Positive statement’ and -1 means a ‘Negative statement’.
#
# **Sentiment_Subjectivity:** This value gives how close a reviewer’s opinion is to the opinion of the general public. Its range is [0,1]. Higher the subjectivity, closer is the reviewer’s opinion to the opinion of the general public, and lower subjectivity indicates the review is more of a factual information.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# Printing unique values for each variable in the Play Store Dataset
print('Unique Values for each variable in Play Store Dataset:', end='\n')

for i in play_store_app_df1.columns.tolist():
    print("No. of unique values in ", i, "is ->", play_store_app_df1[i].nunique())

print('\n')

# Printing unique values for each variable in the User Reviews Dataset
print('Unique Values for each variable in User Reviews Dataset:', end='\n')

for i in play_store_user_review_df2.columns.tolist():
    print("No. of unique values in ", i, "is ->", play_store_user_review_df2[i].nunique())
# Out:
# Unique Values for each variable in Play Store Dataset:
# No. of unique values in  App is -> 9659
# No. of unique values in  Category is -> 33
# No. of unique values in  Rating is -> 40
# No. of unique values in  Reviews is -> 5330
# No. of unique values in  Size is -> 459
# No. of unique values in  Installs is -> 20
# No. of unique values in  Type is -> 2
# No. of unique values in  Price is -> 92
# No. of unique values in  Content Rating is -> 6
# No. of unique values in  Genres is -> 118
#
#
# Unique Values for each variable in User Reviews Dataset:
# No. of unique values in  App is -> 865
# No. of unique values in  Translated_Review is -> 27994
# No. of unique values in  Sentiment is -> 3
# No. of unique values in  Sentiment_Polarity is -> 5410
# No. of unique values in  Sentiment_Subjectivity is -> 4474

# %% [markdown]
# ## ***3. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 - Bar Chart -- **Number of Installs for each Category**

# %%
# visualization code
# Category verses Installation bar chart
# setup the plot
plt.figure(figsize=(10,8))

# create the bar plot
play_store_app_df1.groupby('Category')['Installs'].sum().sort_values(ascending=True).plot(kind="barh")

plt.xticks(size=10)
plt.xlabel("Installs",size=12,c="k")
plt.ylabel("Category",size=12,c="k")
plt.title("Number of Install for each Category",size=16,c="k")
# display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts should be used when we are showing segments of information. It is a good choice for visualizing the number of installs for different app categories because it allows us for easy comparison between categories.The horizontal layout also makes it easier to read the category labels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above bar chart we can observe that most of the apps being downloaded and installed belong to the GAMES category, indicating high demands for GAMES. After Games,there are COMMUNICATION and TOOLS apps which mostly downloaded.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can conclude from the following visualization that the Play Store's GAME category list will boost business profit. Comparably, businesses in the EVENT, BEAUTY, MEDICAL, and PARENTING sectors need to reinvent their offerings in order to differentiate themselves from the competition and attract more clients. This may contribute to their market's improvement.

# %% [markdown]
# #### Chart - 2- Bar Chart -- **Total number of apps in each category**

# %%
# visualization code
# Category versus total number of Apps
# setup the plot
plt.figure(figsize=(12,6))

# create horizontal bar plot
play_store_app_df1.groupby('Category')['App'].nunique().sort_values(ascending=True).plot(kind="barh")
plt.xticks(size=10)
plt.xlabel("Total Apps",size=12,c="k")
plt.ylabel("Category",size=12,c="k")
plt.title("Number of apps for each Category",size=16,c="k")
# display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts should be used when we are showing segments of information. It is a good choice for visualizing the number of apps for each categories because it allows us for easy comparison between categories.The horizontal layout also makes it easier to read the category labels
# .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above chart we found that highest number of app present in 'Family' category follwed by 'Games' and 'Tools' category

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Above chart shows that Beauty, Comics categories have less number of apps as compared to Family, Game category so it's better to list app in play store like Beauty,Comics

# %% [markdown]
# #### Chart - 3 - Pie Chart -- **Content ratings on number of apps**

# %%
# visualization code
#setup the plot
plt.figure(figsize=(8,6))
# label the title
plt.title("Content ratings on apps",fontsize = 16)
# ceate the pie plot
plt.pie(play_store_app_df1['Content Rating'].value_counts(), labels=play_store_app_df1['Content Rating'].value_counts().index,autopct='%1.1f%%',startangle=180,explode=(0.1,0,0,0,1,2.5))
# display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart helps organize and show data as a percentage of a whole and slices of that circle or pie, to represent the specific categories that compose the whole.
# Here we display the percentage of Apps with Content rating which having different age group restriction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we observed that 'Adults only 18+' and 'Unrated' are with very less number of apps and  'Everyone' has higest number of percentage of apps which means most of the apps are available for everyone without any age restriction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Above pie chart implies that most of the apps are belong to 'Everyone' rating which means they will gain more users But for businesses targeting specific age groups, like 'Mature 17+' or 'Adults only 18+' can be useful as there is less competition in those areas.

# %% [markdown]
# #### Chart - 4 -- Pie Chart -- **Type of different apps in play store**

# %%
# visualization code
# pie chart showing percentage of paid verses free apps in play store
# setup the plot
plt.figure(figsize=(7,7))
# label the title of plot
plt.title("Price of apps",fontsize = 16)
# create the pie plot
plt.pie(play_store_app_df1.Type.value_counts(), labels=play_store_app_df1.Type.value_counts().index,autopct='%1.1f%%',startangle=180,explode=(0, 0.1))
# display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart helps to organize and show data as a percentage of a whole and slices of that circle or pie, to represent the specific categories that compose the whole. Here we display the percentage of type of different apps in play store

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The larger slice of the pie chart represents the free apps, with 92.2% of the total. The smaller slice representing paid apps, with 7.8% of the total. This indicates that the vast majority of apps on the Google Play Store are free to download and use.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here maximum percentage of free apps listing in play store than paid apps. so paid type apps may lead to less insatallation. we also say that offering free apps can be a successful business strategy to attract users.

# %% [markdown]
# #### Chart - 5 -- Box Plot -- **Distribution of Free vs. Paid Apps by Category**

# %%
# visualization code
# grouping data by category and type
category_counts = play_store_app_df1.groupby(['Category', 'Type']).count()['App'].unstack()

# ploting stacked bar chart
category_counts.plot(kind='bar', stacked=True)
# set the labels for title and axes
plt.title("Distribution of Free vs. Paid Apps by Category")
plt.xlabel("Category")
plt.ylabel("Number of Apps")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because it makes it easy to compare the quantity of free and paid apps in each category as well as the distribution of free and paid apps overall across all categories, I chose a stacked bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Popular categories like "FAMILY," "GAMES," and "TOOLS" contain a lot of free apps, making it difficult to make money alone from app purchases. As a result, developers and businesses building apps in these categories should look into alternative revenue streams.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Businesses and developers can use this information to make informed choices about which categories to concentrate on. They could option to focus on the "Family" or "Game" category if they intend to develop a paid app. Alternatively, they might look at the "Beauty," "Art and Design," and "Comics" categories if they want to make a free app with less competition.

# %% [markdown]
# #### Chart - 6 -- Box Plot -- **Distribution of Rating on category**

# %%
#vistualization code
# setup the plot
plt.figure(figsize=(10,6))

# create box plot
sns.boxplot(y="Category",x ='Rating',data =play_store_app_df1)

# label the title of plot
plt.title("Rating on Category",fontsize=16)
plt.xlabel("Rating",fontsize=12)
plt.ylabel("Category",fontsize=10)
# display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box plot visually show the distribution of numerical data and skewness
# by displaying the data quartiles and averages. It displays the summary of the set of data values including minimum,first quartile,median,third quartile and maximum

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Above distribution of ploting shows that maximum number of apps in the play store are rated between range 4 and 4.6. It means users are happy with them

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here most apps have high ratings, which shows that users are generally satisfied with the apps available on the Play Store. This could result in increased user trust which can lead to higher app downloads, increased revenue, and a better overall reputation for the app store.

# %% [markdown]
# #### Chart - 7 -- Histogram -- **Distribution of size**

# %%
# visualization code
# setup the plot
plt.figure(figsize=(8, 6))

# create the histogram
plt.hist(play_store_app_df1['Size'],color = "blue")

# set the labels for axes and title of plot
plt.xlabel("Size",fontsize=14)
plt.title("Distribution of Size",fontsize=16)
plt.ylabel("Number of apps",fontsize=14)
# display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram is good for the graphical representation of numerical data distribution.so for better undersating of different sizes of apps histogram used.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above plot we observed that maximum number of the app's size is between 1 to 20Mb. it means most of the apps are small in size

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the histogram we observed that most of the apps are small in size between 1Mb to 20Mb,so if apps size increases there may be possibilites that few number of apps get install.Focusing on developing apps within the preferred size ranges may result in a positive impact on business growth

# %% [markdown]
# #### Chart - 8 -- Bar chart -- **Revenue by Category**

# %%
# Visualization code
# Calculate Revenue for each app
play_store_app_df1['Revenue'] = play_store_app_df1['Installs'] * play_store_app_df1['Price']

# Group by Category and calculate the mean revenue, sorted in descending order
category_revenue = play_store_app_df1.groupby('Category')['Revenue'].mean().sort_values(ascending=False)

# Select the top 10 categories
top_10_categories_revenue = category_revenue.head(10)

# Set up the plot
plt.figure(figsize=(10, 5))

# Create a bar plot for the top 10 categories
sns.barplot(x=top_10_categories_revenue.values, y=top_10_categories_revenue.index, palette='Set3')

# set the labels for the axes and title
plt.title('Top 10 Categories by Average Revenue',size=20)
plt.xlabel('Average Revenue (USD)',size=15)
plt.ylabel('Category',size=15)
# display the plot
plt.show()
# Out:
# <ipython-input-55-98b04a2179a1>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_categories_revenue.values, y=top_10_categories_revenue.index, palette='Set3')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It is a good choice for visualize the revenue generated by each category in a clear way.The horizontal layout also makes it easier to read the category labels .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top three revenue-generating categories—Living, Finance, and Family—show that users are willing to spend money on goods and services related to their personal lives and finances.
#
# In contrast, the Sports category has the lowest average revenue, which suggests that users do not find it particularly popular. Comparably, the Medical category has the second-lowest average revenue, suggesting that apps in this category may face difficulties with security or convenience.With the third-lowest average revenue, the Personalization category may indicate comparatively lower user interest.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Companies can strategically concentrate on developing and improving apps within these genres by utilizing the knowledge about the top revenue-generating categories, such as Lifestyle, Finance, and Family. This is consistent with user preferences and their tendency to spend money on financial and personal products.
#
# Businesses can take advantage of the growing trend of spending on experiences related to entertainment and leisure by achieving the revenue potential in the game, photography, and family categories. In order to engage users and make money, developers can produce entertaining and engaging apps in these categories.
#
# Businesses may find it difficult to make a significant profit if they have a lot of investment in these areas. While this does not always result in negative growth, it does highlight areas that may need to be evaluated strategically and possibly adjusted.

# %% [markdown]
# #### Chart - 9 -- Scatterplot -- **Distribution of apps in terms of rating, size and type**

# %%
# visualization code
# set up the plot
plt.figure(figsize=(12, 6))

# create scatter plot
sns.scatterplot(data=play_store_app_df1,x=play_store_app_df1['Size'],y=play_store_app_df1['Rating'],hue=play_store_app_df1['Type'],s=50)

# labele the axis and title
plt.xlabel("Size",fontsize=14)
plt.ylabel("Rating",fontsize=14)
plt.title("Apps rating, size and type",fontsize=15)
# display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots are used to plot data points on horizontal and vertical axis in the attempt to show how much one variable is affected by another.so it will give a proper visualization between apps rating,size and type

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# here from above plot we can observe that maximum numbers of the free
# apps are small in size with high rating. where as, paid apps have quite equal distribution in term of size and rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  From above observation we can say that, the apps which are small in size it may lead to high installations and reviews.

# %% [markdown]
# #### Chart - 10 -- Line Chart -- **Review, size, installs, price per rating**

# %%
# visualization code
# plot the graphs of reviews, size, installs and price per rating
# grouped by rating and calulate the sum
df_Rating = play_store_app_df1.groupby('Rating').sum().reset_index()

# set up the plot
fig, axes = plt.subplots(1, 4, figsize=(10, 4))

axes[0].plot(df_Rating['Rating'], df_Rating['Size'], 'm')
axes[0].set_title('Size Per Rating',fontsize=14)
axes[0].set_xlabel('Rating')
axes[0].set_ylabel('Size')

axes[1].plot(df_Rating['Rating'], df_Rating['Reviews'], 'g')
axes[1].set_title('Reviews Per Rating',fontsize=14)
axes[1].set_xlabel('Rating')
axes[1].set_ylabel('Reviews')


axes[2].plot(df_Rating['Rating'], df_Rating['Installs'], 'y')
axes[2].set_title('Installs Per Rating',fontsize=14)
axes[2].set_xlabel('Rating')
axes[2].set_ylabel('Installs (e+10)')

axes[3].plot(df_Rating['Rating'], df_Rating['Price'], 'r')
axes[3].set_title('Price Per Rating',fontsize=14)
axes[3].set_xlabel('Rating')
axes[3].set_ylabel('Price')

plt.tight_layout(pad=2)
# display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line charts aid in identifying major performance concerns and spotting patterns (either good or bad). Line charts allow you to pinpoint the precise moment when anything out of the norm occurred, which aids in determining where to go for solutions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here from above plot, we can observe that maximum number of the apps with higher rating range of 4.0 - 4.7 are having high amount of reviews, size, and installs. But in terms of price, it doesn't shows a direct relationship with rating, as we could see a fluctuation in term of pricing even at the range of high rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The popularity of apps or ratings of apps is strongly correlated with the number of reviews, the size of the app, and the number of installs.

# %% [markdown]
# #### Chart - 11-- Bar chart --**Category with highest number of reviews**

# %%
# visualizaton code
# merge the data on the app
merged_data = pd.merge(play_store_app_df1, play_store_user_review_df2, on='App')

# calculating the number of reviews by category
reviews_by_category = merged_data.groupby("Category")["Translated_Review"].count().sort_values(ascending=False)

# setup the plot
plt.figure(figsize=(10, 6))
# creating bat plot
sns.barplot(x=reviews_by_category.values, y=reviews_by_category.index, palette="Greens_r")
# label the axis and title
plt.xlabel("Number of Reviews")
plt.ylabel("Category")
plt.title("Number of Reviews by Category")

# display the plot
plt.show()
# Out:
# <ipython-input-58-e39e4c6f4e2c>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=reviews_by_category.values, y=reviews_by_category.index, palette="Greens_r")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It is simple and easy to understand the distribution of reviews across different app categories.It allows for easy comparison of the number of reviews for each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that the category with the most reviews is GAME, followed by HEALTH_AND_FITNESS and FAMILY.It indicates that there are a lot of active users in the GAME category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The above visualization provides insights into which categories have a large and active user base. This information may help marketers and app developers focus their efforts in these areas.It also emphasizes how crucial it is to give customers a satisfying experience in order to motivate them to write reviews, which can eventually boost an app's exposure and download count.

# %% [markdown]
# #### Chart - 12 - **Correlation Heatmap**

# %%
# visualization code
# Select only numeric columns from the DataFrame
numeric_columns_df = play_store_app_df1.select_dtypes(include=['float64', 'int64'])

# setup the plot
plt.figure(figsize=(10, 7))
# Generate the heatmap using the selected numeric columns
sns.heatmap(numeric_columns_df.corr(), annot=True,cmap='rocket', fmt=".2f")
plt.title("Correlation by Heatmap in Play Store Data", fontsize=20)
# display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is a powerful tool for identifying relationships between pairs of variables in a dataset. The color-coding allows us to see at a glance whether variables are positively correlated (similar movements) or negatively correlated (opposite movements). The colors in the heatmap represent the strength of the correlation, with brighter colors indicating stronger correlations and darker colors indicating weaker or no correlations. The range of correlation is from -1 to 1. So, I used a correlation heatmap to find the relationships among Rating, Reviews, Installs, Price, Sentiment_Polarity, and Sentiment_Subjectivity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Rating has a moderate positive correlation with Reviews, Installs. This means that apps with higher ratings tend to have more reviews, more installs. Rating has a weak negative correlation with Price. This means that apps with higher ratings tend to be slightly cheaper.
#
# Reviews has a strong positive correlation with Installs. This means that apps with more reviews tend to have more installs. Reviews has a weak negative correlation with Price. This means that apps with more reviews tend to be slightly cheaper.
#
# Installs has a weak negative correlation with Price. This means that apps with more installs tend to be slightly cheaper.

# %% [markdown]
# #### Chart - 13 -- Pie Chart -- **Sentiment Polarity Distribution**

# %%
# visualization code
# histograme based on polarity
# set up the plot
plt.figure(figsize=(10,6))
# create the histogram
plt.hist(play_store_user_review_df2[play_store_user_review_df2['Sentiment_Polarity'].notnull()]['Sentiment_Polarity'],color = "Green")
plt.xlabel("Polarity",fontsize=14)
plt.title("Distribution of sentiment polarity",fontsize=14)
# display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram is good for the graphical representation of numerical data distribution.so for better undersating of distribution of sentiment polarity histogram used.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# from the above plot it can see that maximum number of sentiment polarity lies between 0.0 to 0.50

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From above insight we can say that most of user have positive sentiment reviews which will helpful for business.

# %% [markdown]
# #### Chart - 14--Histogram-- **#  Subjectivity Distribution**

# %%
# visualziation code
#histogram based on subjectivity
# set up the plot
plt.figure(figsize=(10,6))
# create the histogram
plt.hist(play_store_user_review_df2[play_store_user_review_df2['Sentiment_Subjectivity'].notnull()]['Sentiment_Subjectivity'],color = "skyblue")
# set labels for axis and title of the plot
plt.xlabel("Subjectivity",fontsize=16)
plt.title("Distribution of Subjectivity",fontsize=16)
# display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram is good for the graphical representation of numerical data distribution.so for better undersating of distribution of sentiment subjectivity histogram used.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It observe that maximum number of sentiment subjectivity lies between 0.4 to 0.7. From this we can conclude that maximum number of users give reviews to the applications, according to their experience.
# Here, 0 =objective(fact), 1 =subjective(opinion)

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As maximum number of sentiment subjectivity lies betwen 0.4 to 0.7 we say that most users rate the apps on basis of their own experience with the application.

# %% [markdown]
# #### Chart - 15--Histogram-- **Sentiment Analysis based on Category**

# %%
# visualization code
from matplotlib.ticker import PercentFormatter
merged_df = pd.merge(play_store_app_df1, play_store_user_review_df2, on='App', how = 'inner')
merged_df.head()
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,1,1)

# Create a histogram plot using seaborn
sns.histplot(
    data=merged_df,
    x="Category", hue="Sentiment",
    bins=30,
    ax=ax,
    stat="count",
    multiple="stack",
    palette="light:salmon_r",
    edgecolor=".3",
    linewidth=.5,
    legend=True
    )
# Set the title of the plot
ax.set_title("Sentiment Analysis Based on Category",fontsize=10)
plt.xticks(rotation='vertical')
# Set labels for the x and y axes
ax.set_xlabel("Category",fontsize=12)
ax.set_ylabel("Review Counts",fontsize=12)

plt.gca().yaxis.set_major_formatter(PercentFormatter(20000))
sns.set(style="ticks")
plt.grid()
# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We picked Stacked Histogram because it helps to visualize the sentiment analysis based on categories in the reviews data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It indicates which app categories receive the most positive and negative reviews. It appears that the "GAME" category has the most reviews, both positive and negative. However, there are more negative evaluations than positive ones, thus the app developers should investigate and resolve the issues. On the other hand, the "COMICS" category has only a few evaluations, both positive and negative.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Companies are able to pinpoint the parts of their apps that require development. They may be able to enhance user experiences and app quality as a result, increasing consumer satisfaction and loyalty. As a consequence, it can improve their company's reputation and possibly boost sales.

# %% [markdown]
# #### Chart -16--Scatterplot-- **Relationship between Sentiment Subjectivity and Sentiment Polarity**

# %%
# visualization code
# Set the size of the figure
plt.figure(figsize=(12, 6))

# Create a scatter plot using seaborn
sns.scatterplot(data=merged_df, x='Sentiment_Subjectivity', y='Sentiment_Polarity', hue='Sentiment', palette='Set2')

# Set labels for the x and y axes
plt.xlabel('Sentiment Subjectivity', size=15)
plt.ylabel('Sentiment Polarity', size=15)

# Set the title of the plot
plt.title('Relationship between Sentiment Subjectivity and Sentiment Polarity', size=15)

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because they make it easy to spot patterns and correlations in the data, scatter plots are an effective tool for exploratory data analysis. We can color-code the data points according to a third variable by using the hue parameter, which facilitates the process of finding patterns and correlations between the variables. Thus, I represented the sentiment variable by hue in a scatter plot and used it to find patterns between sentiment subjectivity and sentiment polarity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Sentiment Subjectivity and Sentiment Polarity exhibit a moderately positive correlation in their scatter plot. This indicates that sentiment subjectivity generally tends to increase along with sentiment polarity. But it's not a particularly strong relationship. This shows that when people are feeling good about themselves, they tend to voice their opinions more strongly than when they are feeling bad.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Reviewing the correlation could provide information about the features of products and services that produce strong positive feelings. This data can be used by businesses to improve and prioritize the elements that increase customer satisfaction.
#
# Recognizing the correlation, businesses can focus on creating platforms for customers to share their positive experiences in a more detailed and expressive manner. This could include encouraging reviews, testimonials, or social media interactions that capture the enthusiasm of satisfied customers.

# %% [markdown]
# ## ***4. Solution to Business Objective***

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# As per above EDA there are some useful insights for the client to achieve their business objective
#
# Businesses should focus on developing and improving apps in popular categories like games, communication and tools and find ways to differentiate their apps from competitors to increase their chances of success
#
# The majority of apps on the Play Store have a content rating of 'Everyone', followed by 'Teen' and 'Everyone 10+'. This information can be helpful for app developers to understand the content rating distribution of apps and ensure their app aligns with the appropriate content rating and make any necessary changes to improve their app's rating.
#
# The majority of apps in the Play Store dataset are free, indicating that users prefer free apps. This information can be valuable for app developers to understand user preferences and adjust their monetization strategy accordingly. Developers should consider offering in-app purchases, ads, or other revenue-generating options to supplement their income from free apps. Additionally, developers of paid apps should ensure that their app provides significant value to justify the cost to users.
#
# Businesses should aim to maintain high app ratings between 4.0 and 4.5, and improving apps with less rating to increase user satisfaction. This could be achieved by gathering user feedback as well as implementing new features or improvements to enhance the overall user experience.
#
# Recognize the preference for smaller apps, as indicated by the popularity of the below 20 and 20-40 MB size groups. Ensure that new app developments and updates prioritize efficiency and minimal storage requirements to align with user preferences for smaller-sized apps.
#
# Businesses should focus on app categories with a high number of user reviews, such as games, health and fitness, and family, as these categories have a large and engaged user base. For categories with a similar number of reviews, such as dating and travel and local, businesses should consider other factors such as user satisfaction and competition when developing or improving apps in these categories.
#
# Developers should focus on improving the user experience and encouraging positive reviews to increase app installs. They should also consider pricing strategies that attract users while generating revenue.
#
# Identify the characteristics of apps with consistently positive sentiment and leverage those aspects in future app development. Encourage and amplify positive user experiences through marketing and feature enhancements.
#
# Investigate apps with negative sentiment to pinpoint specific issues causing dissatisfaction. Prioritize improvements in areas highlighted by negative sentiment to enhance user satisfaction and overall app performance.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# With the help of Python, this project has successfully analyzed the Play Store app dataset, providing insightful information about the critical elements that influence app engagement and success. A complete understanding of user sentiment, app ratings, genre preferences, content suitability, and the effects of updates is offered by the data visualizations and interpretations.
#
# I have created useful suggestions for the client to maximize app performance and accomplish their business goals based on these insights. I suggest they concentrate on growing a positive attitude, quickly resolving user complaints, allowing user preferences such as frequent updates and smaller apps, strategically focusing on particular genres and content ratings, and developing dedicated followers in particular markets.
#
#
# Through the adoption of a data-driven strategy and ongoing user preference adjustments, the client can guarantee sustained success in the highly competitive Android app market

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
